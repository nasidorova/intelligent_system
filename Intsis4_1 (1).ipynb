# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2

# Загрузка данных MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 784).astype('float32') / 255.0
x_test = x_test.reshape(-1, 784).astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Создание модели
model = Sequential()
model.add(Input(shape=(784,))) #Слой нейронов для получения данных
model.add(Dense(128, activation='relu'))
#model.add(Dense(128, activation='relu'))
#model.add(Dense(128, activation='relu'))
#model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))#Выходной слой нейронов

# Компиляция модели
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error', metrics=['accuracy'])
                                                    #mean_squared_error
# Обучение модели
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))

# Оценка модели
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/15
# 2024-05-22 19:34:36.200373: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 188160000 exceeds 10% of free system memory.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.8308 - loss: 0.0236 - val_accuracy: 0.9534 - val_loss: 0.0072
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9587 - loss: 0.0065 - val_accuracy: 0.9641 - val_loss: 0.0057
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9660 - loss: 0.0054 - val_accuracy: 0.9636 - val_loss: 0.0059
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9690 - loss: 0.0051 - val_accuracy: 0.9567 - val_loss: 0.0072
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9695 - loss: 0.0051 - val_accuracy: 0.9545 - val_loss: 0.0080
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9708 - loss: 0.0050 - val_accuracy: 0.9640 - val_loss: 0.0064
# Epoch 7/15
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2

# Загрузка данных MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 784).astype('float32') / 255.0
x_test = x_test.reshape(-1, 784).astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Создание модели
model = Sequential()
model.add(Input(shape=(784,))) #Слой нейронов для получения данных
model.add(Dense(128, activation='sigmoid'))
#model.add(Dense(128, activation='tanh'))
#model.add(Dense(128, activation='relu'))
#model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))#Выходной слой нейронов

# Компиляция модели
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error', metrics=['accuracy'])
                                                    #mean_squared_error
# Обучение модели
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))

# Оценка модели
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8387 - loss: 0.0227 - val_accuracy: 0.9585 - val_loss: 0.0065
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9619 - loss: 0.0060 - val_accuracy: 0.9688 - val_loss: 0.0049
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9735 - loss: 0.0041 - val_accuracy: 0.9673 - val_loss: 0.0050
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9779 - loss: 0.0035 - val_accuracy: 0.9711 - val_loss: 0.0044
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9835 - loss: 0.0027 - val_accuracy: 0.9726 - val_loss: 0.0041
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9839 - loss: 0.0026 - val_accuracy: 0.9717 - val_loss: 0.0043
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9868 - loss: 0.0022 - val_accuracy: 0.9758 - val_loss: 0.0038
# Epoch 8/15
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2

# Загрузка данных MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 784).astype('float32') / 255.0
x_test = x_test.reshape(-1, 784).astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Создание модели
model = Sequential()
model.add(Input(shape=(784,))) #Слой нейронов для получения данных
model.add(Dense(128, activation='hard_sigmoid'))
#model.add(Dense(128, activation='tanh'))
#model.add(Dense(128, activation='relu'))
#model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))#Выходной слой нейронов

# Компиляция модели
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error', metrics=['accuracy'])
                                                    #mean_squared_error
# Обучение модели
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))

# Оценка модели
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7904 - loss: 0.0287 - val_accuracy: 0.9516 - val_loss: 0.0073
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9608 - loss: 0.0061 - val_accuracy: 0.9657 - val_loss: 0.0054
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9732 - loss: 0.0043 - val_accuracy: 0.9626 - val_loss: 0.0057
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9773 - loss: 0.0036 - val_accuracy: 0.9699 - val_loss: 0.0045
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9800 - loss: 0.0031 - val_accuracy: 0.9697 - val_loss: 0.0046
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9841 - loss: 0.0026 - val_accuracy: 0.9714 - val_loss: 0.0044
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9847 - loss: 0.0025 - val_accuracy: 0.9685 - val_loss: 0.0049
# Epoch 8/15
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2

# Загрузка данных MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 784).astype('float32') / 255.0
x_test = x_test.reshape(-1, 784).astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Создание модели
model = Sequential()
model.add(Input(shape=(784,))) #Слой нейронов для получения данных
model.add(Dense(128, activation='hard_sigmoid'))
model.add(Dense(128, activation='hard_sigmoid'))
model.add(Dense(128, activation='hard_sigmoid'))
model.add(Dense(128, activation='hard_sigmoid'))
#model.add(Dense(128, activation='relu'))
#model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))#Выходной слой нейронов

# Компиляция модели
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error', metrics=['accuracy'])
                                                    #mean_squared_error
# Обучение модели
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))

# Оценка модели
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6041 - loss: 0.0464 - val_accuracy: 0.9435 - val_loss: 0.0089
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9477 - loss: 0.0082 - val_accuracy: 0.9576 - val_loss: 0.0066
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9610 - loss: 0.0062 - val_accuracy: 0.9653 - val_loss: 0.0055
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9658 - loss: 0.0054 - val_accuracy: 0.9656 - val_loss: 0.0055
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9709 - loss: 0.0046 - val_accuracy: 0.9705 - val_loss: 0.0049
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.9743 - loss: 0.0042 - val_accuracy: 0.9628 - val_loss: 0.0060
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9753 - loss: 0.0040 - val_accuracy: 0.9678 - val_loss: 0.0051
# Epoch 8/15
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.regularizers import l1, l2

# Загрузка данных MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 784).astype('float32') / 255.0
x_test = x_test.reshape(-1, 784).astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Создание модели
model = Sequential()
model.add(Input(shape=(784,))) #Слой нейронов для получения данных
model.add(Dense(128, activation='hard_sigmoid', kernel_regularizer=l2(0.0001)))

#model.add(Dense(128, activation='hard_sigmoid', kernel_regularizer=l1(0.0001)))
#model.add(Dense(128, activation='hard_sigmoid'))
#model.add(Dense(128, activation='hard_sigmoid'))
#model.add(Dense(128, activation='sigmoid'))
#model.add(Dense(128, activation='sigmoid'))
#model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))#Выходной слой нейронов

# Компиляция модели
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error', metrics=['accuracy'])
                                                    #mean_squared_error
# Обучение модели
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))

# Оценка модели
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7877 - loss: 0.0429 - val_accuracy: 0.8827 - val_loss: 0.0271
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8740 - loss: 0.0287 - val_accuracy: 0.8920 - val_loss: 0.0266
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8874 - loss: 0.0269 - val_accuracy: 0.8970 - val_loss: 0.0240
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8992 - loss: 0.0243 - val_accuracy: 0.9010 - val_loss: 0.0240
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9049 - loss: 0.0228 - val_accuracy: 0.9149 - val_loss: 0.0214
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9109 - loss: 0.0220 - val_accuracy: 0.9117 - val_loss: 0.0212
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9153 - loss: 0.0209 - val_accuracy: 0.9182 - val_loss: 0.0199
# Epoch 8/15
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2

# Загрузка данных MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 784).astype('float32') / 255.0
x_test = x_test.reshape(-1, 784).astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Создание модели
model = Sequential()
model.add(Input(shape=(784,))) #Слой нейронов для получения данных
model.add(Dense(784, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(392, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(196, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(10, activation='relu', kernel_regularizer=l2(0.01)))
#model.add(Dense(128, activation='relu'))
#model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))#Выходной слой нейронов

# Компиляция модели
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error', metrics=['accuracy'])
                                                    #mean_squared_error
# Обучение модели
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))

# Оценка модели
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.1063 - loss: 0.7357 - val_accuracy: 0.1135 - val_loss: 0.0900
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.1099 - loss: 0.0900 - val_accuracy: 0.1135 - val_loss: 0.0900
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.1090 - loss: 0.0900 - val_accuracy: 0.1135 - val_loss: 0.0902
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.1121 - loss: 0.0902 - val_accuracy: 0.1135 - val_loss: 0.0901
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.1142 - loss: 0.0901 - val_accuracy: 0.1135 - val_loss: 0.0901
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.1127 - loss: 0.0902 - val_accuracy: 0.1135 - val_loss: 0.0901
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.1091 - loss: 0.0901 - val_accuracy: 0.1135 - val_loss: 0.0902
# Epoch 8/15
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2

# Загрузка данных
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Создание модели
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# Компиляция модели
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error', metrics=['accuracy'])

# Обучение модели
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))

# Оценка модели
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 101ms/step - accuracy: 0.8442 - loss: 0.0214 - val_accuracy: 0.9778 - val_loss: 0.0036
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.9464 - loss: 0.0089 - val_accuracy: 0.9433 - val_loss: 0.0112
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.8412 - loss: 0.0315 - val_accuracy: 0.8906 - val_loss: 0.0219
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.7904 - loss: 0.0419 - val_accuracy: 0.8302 - val_loss: 0.0339
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.7765 - loss: 0.0447 - val_accuracy: 0.8653 - val_loss: 0.0269
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 105ms/step - accuracy: 0.7982 - loss: 0.0404 - val_accuracy: 0.8772 - val_loss: 0.0245
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 105ms/step - accuracy: 0.8094 - loss: 0.0381 - val_accuracy: 0.8911 - val_loss: 0.0218
# Epoch 8/15
# ...
